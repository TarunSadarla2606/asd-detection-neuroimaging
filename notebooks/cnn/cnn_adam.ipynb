# %%
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, confusion_matrix

# Load your pretrained model weights here if needed
#model.load_state_dict(torch.load('your_model_weights.pth'))

# Create empty lists to store training and validation losses and accuracies
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Set the current epoch number to continue from where you left off
current_epoch = 0  # Change this to the epoch you want to continue from

num_epochs = 30  # Set the total number of epochs you want to run

# Continue training for additional epochs
for epoch in range(current_epoch, num_epochs):
    model.train()
    running_train_loss = 0.0
    train_preds = []
    train_targets = []

    # Training loop with a progress bar
    for images, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs} (Training)'):
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        train_preds.extend(predicted.cpu().numpy())
        train_targets.extend(labels.cpu().numpy())

    # Calculate and print the average training loss for this epoch
    avg_train_loss = running_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    
    # Calculate training accuracy for this epoch
    train_accuracy = accuracy_score(train_targets, train_preds)
    train_accuracies.append(train_accuracy)

    model.eval()  # Set the model to evaluation mode
    running_val_loss = 0.0
    val_preds = []
    val_targets = []

    # Validation loop with a progress bar
    for images, labels in tqdm(val_loader, desc=f'Epoch {epoch + 1}/{num_epochs} (Validation)'):
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_val_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        val_preds.extend(predicted.cpu().numpy())
        val_targets.extend(labels.cpu().numpy())

    # Calculate and print the average validation loss for this epoch
    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    
    # Calculate validation accuracy for this epoch
    val_accuracy = accuracy_score(val_targets, val_preds)
    val_accuracies.append(val_accuracy)

    # Print loss and accuracy for this epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}')
    print(f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}%')

print('Finished Training')
torch.save(model.state_dict(), 'your_model_weights.pth')
# Out:
# Epoch 1/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [33:50<00:00,  3.21s/it]
#
# Epoch 1/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.47s/it]
# Epoch [1/30], Training Loss: 1.0031, Training Accuracy: 0.51
#
# Validation Loss: 0.7335, Validation Accuracy: 0.50%
# Epoch 2/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [42:55<00:00,  4.07s/it]
#
# Epoch 2/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:12<00:00,  2.44s/it]
# Epoch [2/30], Training Loss: 0.8342, Training Accuracy: 0.52
#
# Validation Loss: 0.6892, Validation Accuracy: 0.52%
# Epoch 3/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [37:11<00:00,  3.53s/it]
#
# Epoch 3/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:10<00:00,  2.41s/it]
# Epoch [3/30], Training Loss: 0.7546, Training Accuracy: 0.55
#
# Validation Loss: 0.7664, Validation Accuracy: 0.52%
# Epoch 4/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [35:58<00:00,  3.42s/it]
#
# Epoch 4/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:36<00:00,  2.74s/it]
# Epoch [4/30], Training Loss: 0.7728, Training Accuracy: 0.57
#
# Validation Loss: 0.6531, Validation Accuracy: 0.61%
# Epoch 5/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [45:09<00:00,  4.29s/it]
#
# Epoch 5/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:23<00:00,  2.58s/it]
# Epoch [5/30], Training Loss: 0.7221, Training Accuracy: 0.59
#
# Validation Loss: 0.6282, Validation Accuracy: 0.63%
# Epoch 6/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [40:06<00:00,  3.81s/it]
#
# Epoch 6/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.48s/it]
# Epoch [6/30], Training Loss: 0.7274, Training Accuracy: 0.60
#
# Validation Loss: 0.6633, Validation Accuracy: 0.60%
# Epoch 7/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [39:25<00:00,  3.74s/it]
#
# Epoch 7/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.47s/it]
# Epoch [7/30], Training Loss: 0.6985, Training Accuracy: 0.62
#
# Validation Loss: 0.5948, Validation Accuracy: 0.66%
# Epoch 8/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [37:49<00:00,  3.59s/it]
#
# Epoch 8/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.48s/it]
# Epoch [8/30], Training Loss: 0.6456, Training Accuracy: 0.66
#
# Validation Loss: 0.5755, Validation Accuracy: 0.70%
# Epoch 9/30 (Training): 100%|█████████████████████████████████████████████████████████| 632/632 [37:29<00:00,  3.56s/it]
#
# Epoch 9/30 (Validation): 100%|█████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.47s/it]
# Epoch [9/30], Training Loss: 0.6217, Training Accuracy: 0.68
#
# Validation Loss: 0.5592, Validation Accuracy: 0.70%
# Epoch 10/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:26<00:00,  3.46s/it]
#
# Epoch 10/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.47s/it]
# Epoch [10/30], Training Loss: 0.5940, Training Accuracy: 0.70
#
# Validation Loss: 0.5166, Validation Accuracy: 0.74%
# Epoch 11/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [35:57<00:00,  3.41s/it]
#
# Epoch 11/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.48s/it]
# Epoch [11/30], Training Loss: 0.5389, Training Accuracy: 0.73
#
# Validation Loss: 0.4534, Validation Accuracy: 0.78%
# Epoch 12/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:53<00:00,  3.50s/it]
#
# Epoch 12/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [12/30], Training Loss: 0.5087, Training Accuracy: 0.75
#
# Validation Loss: 0.5103, Validation Accuracy: 0.73%
# Epoch 13/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [35:54<00:00,  3.41s/it]
#
# Epoch 13/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.47s/it]
# Epoch [13/30], Training Loss: 0.4586, Training Accuracy: 0.78
#
# Validation Loss: 0.3884, Validation Accuracy: 0.81%
# Epoch 14/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [39:05<00:00,  3.71s/it]
#
# Epoch 14/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:16<00:00,  2.49s/it]
# Epoch [14/30], Training Loss: 0.4355, Training Accuracy: 0.80
#
# Validation Loss: 0.3644, Validation Accuracy: 0.82%
# Epoch 15/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:04<00:00,  3.52s/it]
#
# Epoch 15/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.47s/it]
# Epoch [15/30], Training Loss: 0.3943, Training Accuracy: 0.82
#
# Validation Loss: 0.3336, Validation Accuracy: 0.84%
# Epoch 16/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [38:03<00:00,  3.61s/it]
#
# Epoch 16/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:17<00:00,  2.50s/it]
# Epoch [16/30], Training Loss: 0.3612, Training Accuracy: 0.84
#
# Validation Loss: 0.3120, Validation Accuracy: 0.85%
# Epoch 17/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [41:58<00:00,  3.99s/it]
#
# Epoch 17/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [17/30], Training Loss: 0.3312, Training Accuracy: 0.85
#
# Validation Loss: 0.2822, Validation Accuracy: 0.87%
# Epoch 18/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:17<00:00,  3.54s/it]
#
# Epoch 18/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:12<00:00,  2.44s/it]
# Epoch [18/30], Training Loss: 0.3067, Training Accuracy: 0.86
#
# Validation Loss: 0.2835, Validation Accuracy: 0.87%
# Epoch 19/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:40<00:00,  3.58s/it]
#
# Epoch 19/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [19/30], Training Loss: 0.2876, Training Accuracy: 0.87
#
# Validation Loss: 0.2442, Validation Accuracy: 0.89%
# Epoch 20/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [38:10<00:00,  3.62s/it]
#
# Epoch 20/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:13<00:00,  2.45s/it]
# Epoch [20/30], Training Loss: 0.2662, Training Accuracy: 0.88
#
# Validation Loss: 0.2587, Validation Accuracy: 0.89%
# Epoch 21/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:14<00:00,  3.54s/it]
#
# Epoch 21/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:13<00:00,  2.44s/it]
# Epoch [21/30], Training Loss: 0.2432, Training Accuracy: 0.89
#
# Validation Loss: 0.2290, Validation Accuracy: 0.90%
# Epoch 22/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:49<00:00,  3.59s/it]
#
# Epoch 22/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:13<00:00,  2.44s/it]
# Epoch [22/30], Training Loss: 0.2292, Training Accuracy: 0.90
#
# Validation Loss: 0.2166, Validation Accuracy: 0.90%
# Epoch 23/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:54<00:00,  3.50s/it]
#
# Epoch 23/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:13<00:00,  2.45s/it]
# Epoch [23/30], Training Loss: 0.2228, Training Accuracy: 0.90
#
# Validation Loss: 0.2095, Validation Accuracy: 0.91%
# Epoch 24/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:47<00:00,  3.49s/it]
#
# Epoch 24/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:15<00:00,  2.47s/it]
# Epoch [24/30], Training Loss: 0.1974, Training Accuracy: 0.92
#
# Validation Loss: 0.2051, Validation Accuracy: 0.91%
# Epoch 25/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [41:26<00:00,  3.93s/it]
#
# Epoch 25/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [25/30], Training Loss: 0.1950, Training Accuracy: 0.92
#
# Validation Loss: 0.1848, Validation Accuracy: 0.92%
# Epoch 26/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [37:03<00:00,  3.52s/it]
#
# Epoch 26/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:13<00:00,  2.45s/it]
# Epoch [26/30], Training Loss: 0.1816, Training Accuracy: 0.92
#
# Validation Loss: 0.1790, Validation Accuracy: 0.92%
# Epoch 27/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:41<00:00,  3.48s/it]
#
# Epoch 27/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [27/30], Training Loss: 0.1714, Training Accuracy: 0.93
#
# Validation Loss: 0.1689, Validation Accuracy: 0.92%
# Epoch 28/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [39:22<00:00,  3.74s/it]
#
# Epoch 28/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:22<00:00,  2.56s/it]
# Epoch [28/30], Training Loss: 0.1712, Training Accuracy: 0.93
#
# Validation Loss: 0.1799, Validation Accuracy: 0.92%
# Epoch 29/30 (Training): 100%|████████████████████████████████████████████████████████| 632/632 [36:59<00:00,  3.51s/it]
#
# Epoch 29/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:04<00:00,  2.34s/it]
# Epoch [29/30], Training Loss: 0.1691, Training Accuracy: 0.93
#
# Validation Loss: 0.1779, Validation Accuracy: 0.92%
# Epoch 30/30 (Training): 100%|██████████████████████████████████████████████████████| 632/632 [2:08:10<00:00, 12.17s/it]
#
# Epoch 30/30 (Validation): 100%|████████████████████████████████████████████████████████| 79/79 [03:14<00:00,  2.46s/it]
# Epoch [30/30], Training Loss: 0.1523, Training Accuracy: 0.94
#
# Validation Loss: 0.1904, Validation Accuracy: 0.92%
#
# Finished Training

# %%
#Training vs Validation accuracies
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train_Accuracy', marker='o')
plt.plot(range(1, num_epochs + 1), val_accuracies, label='Val_Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs. Validation Accuracies')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Training vs Validation loss
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.plot(range(1, num_epochs + 1), train_losses, label='Train_Loss')
plt.plot(range(1, num_epochs + 1), val_losses, label='Val_Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, roc_auc_score, roc_curve, confusion_matrix, classification_report, f1_score, recall_score

# Initialize empty lists to store true labels and predicted class probabilities
true_labels = []
predicted_probs = []

# Set the model to evaluation mode
model.eval()

with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        
        # Get the predicted class probabilities using softmax
        predicted_probs.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())  # Probability of class 1
        
        # Store true labels
        true_labels.extend(labels.cpu().numpy())


# Calculate the accuracy
predicted_labels = [1 if prob >= 0.5 else 0 for prob in predicted_probs]
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate the AUC
roc_auc = roc_auc_score(true_labels, predicted_probs)

# Calculate precision, recall, and F1 score
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# Calculate sensitivity (True Positive Rate)
conf_matrix = confusion_matrix(true_labels, predicted_labels)
sensitivity = conf_matrix[1, 1] / (conf_matrix[1, 1] + conf_matrix[1, 0])

# Calculate specificity (True Negative Rate)
specificity = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[0, 1])

# Print the results
print(f'AUC: {roc_auc:.2f}')
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall (Sensitivity): {recall:.2f}')
print(f'Specificity: {specificity:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# AUC: 0.98
#
# Accuracy: 0.92
#
# Precision: 0.91
#
# Recall (Sensitivity): 0.94
#
# Specificity: 0.91
#
# F1 Score: 0.92

# %%
import matplotlib.pyplot as plt

# ROC Curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probs)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Access values from the confusion matrix
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]
TP = conf_matrix[1, 1]

# Now you can use these values as needed

# Define the confusion matrix
conf_matrix = np.array([[TN, FP], [FN, TP]])  

# Confusion Matrix
plt.figure(figsize=(6, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)

# Annotate cells with their values
thresh = conf_matrix.max() / 2.0  # Set a threshold for text coloring
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, str(conf_matrix[i, j]), horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks([0, 1], ['Predicted 0', 'Predicted 1'])
plt.yticks([0, 1], ['Actual 0', 'Actual 1'])
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %%
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np

class CustomDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data = pd.read_csv(csv_file)
        self.transform = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        img_path = self.data.iloc[index, 1]  # 'Image_paths' is the column containing file paths
        img_path = img_path.replace("E:\\TARUN\\Projects\\Autism Detection\\Data\\data_png",'/kaggle/input/autism')
        img_path = img_path.replace("\\",'/')

        image = Image.open(img_path)
        
        # Convert single-channel image to RGB
        if image.mode == 'L':
            image = image.convert('RGB')

        label = int(self.data.iloc[index, 3])  # 'LABEL' is the column containing labels (0 or 1)

        if self.transform:
            image = self.transform(image)
        
        # Convert PIL image to a NumPy array
        image = np.array(image)

        return image, label

# Load your dataset without normalization for the mean and std calculation
raw_dataset = CustomDataset('/kaggle/input/autism-csv/extracted_random_labels.csv', transform=None)
# Initialize lists to store channel-wise mean and standard deviation
channel_means = [0.0, 0.0, 0.0]
channel_stds = [0.0, 0.0, 0.0]

# Iterate through your dataset to calculate channel-wise mean and std
for sample in raw_dataset:
    image, _ = sample  # Assuming the label is not used for this calculation
    for i in range(3):  # Assuming your images have 3 channels (R, G, B)
        channel_means[i] += image[i, :, :].mean()
        channel_stds[i] += image[i, :, :].std()

# Calculate the mean and std values across the entire dataset
num_samples = len(raw_dataset)
mean = [c_mean / num_samples for c_mean in channel_means]
std = [c_std / num_samples for c_std in channel_stds]

# Define the transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to 224x224 pixels
    transforms.ToTensor(),  # Convert to a PyTorch tensor
    transforms.Normalize(mean, std)  # Normalize using the calculated mean and std
])

# Define batch size
batch_size = 64

# Create train and test data loaders
train_dataset = CustomDataset('/kaggle/input/autism-csv/extracted_random_labels_train.csv', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = CustomDataset('/kaggle/input/autism-csv/extracted_random_labels_test.csv', transform=transform)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

val_dataset = CustomDataset('/kaggle/input/autism-csv/extracted_random_labels_validation.csv', transform=transform)
val_loader = DataLoader(val_dataset, batch_size=batch_size)

# %%
print(f"Train dataset size: {len(train_dataset)}")
print(f"Test dataset size: {len(test_dataset)}")
print(f"Test dataset size: {len(val_dataset)}")
# Out:
# Train dataset size: 72367
# Test dataset size: 20102
# Test dataset size: 8041

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Check if a GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the CNN model
class Autism_AdamCNN(nn.Module):
    def __init__(self):
        super(Autism_AdamCNN, self).__init__()
        
        # Convolution Layer 1 (16 filters, Window size = 3x3) + Leaky ReLU
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1)
        self.leakyrelu1 = nn.LeakyReLU(0.1)
        
        # Maxpooling Layer 1 (Window size=2x2)
        self.maxpool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Dropout Layer 1 (Proportion = 20%)
        self.dropout1 = nn.Dropout2d(p=0.2)
        
        # Convolution Layer 2 (32 filters, Window size = 3x3) + Leaky ReLU
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.leakyrelu2 = nn.LeakyReLU(0.1)
        
        # Batch Normalization Layer 1
        self.batchnorm1 = nn.BatchNorm2d(32)
        
        # Maxpooling Layer 2 (Window size=2x2)
        self.maxpool2 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Dropout Layer 2 (Proportion = 20%)
        self.dropout2 = nn.Dropout2d(p=0.2)
        
        # Convolution Layer 3 (64 filters, Window size = 3x3) + Leaky ReLU
        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.leakyrelu3 = nn.LeakyReLU(0.1)
        
        # Batch Normalization Layer 2
        self.batchnorm2 = nn.BatchNorm2d(64)
        
        # Maxpooling Layer 3 (Window size=2x2)
        self.maxpool3 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Dropout Layer 3 (Proportion = 20%)
        self.dropout3 = nn.Dropout2d(p=0.2)
        
        # Convolution Layer 4 (128 filters, Window size = 3x3) + Leaky ReLU
        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.leakyrelu4 = nn.LeakyReLU(0.1)
        
        # Batch Normalization Layer 3
        self.batchnorm3 = nn.BatchNorm2d(128)
        
        # Maxpooling Layer 4 (Window size=2x2)
        self.maxpool4 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Dropout Layer 4 (Proportion = 20%)
        self.dropout4 = nn.Dropout2d(p=0.2)
        
        # Convolution Layer 5 (256 filters, Window size = 3x3) + Leaky ReLU
        self.conv5 = nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1)
        self.leakyrelu5 = nn.LeakyReLU(0.1)
        
        # Batch Normalization Layer 4
        self.batchnorm4 = nn.BatchNorm2d(256)
        
        # Maxpooling Layer 5 (Window size=2x2)
        self.maxpool5 = nn.MaxPool2d(kernel_size=2, stride=2)
        
        # Dropout Layer 5 (Proportion = 20%)
        self.dropout5 = nn.Dropout2d(p=0.2)
        
        # Flattening Layer
        self.flatten = nn.Flatten()
        
        # Fully Connected Layer (Neurons = 100) + Leaky ReLU
        self.fc1 = nn.Linear(7*7*256, 100)
            
    def forward(self, x):
        # Forward pass through the layers
        x = self.leakyrelu1(self.conv1(x))
        x = self.maxpool1(x)
        x = self.dropout1(x)
        
        x = self.leakyrelu2(self.conv2(x))
        x = self.batchnorm1(x)
        x = self.maxpool2(x)
        x = self.dropout2(x)
        
        x = self.leakyrelu3(self.conv3(x))
        x = self.batchnorm2(x)
        x = self.maxpool3(x)
        x = self.dropout3(x)
        
        x = self.leakyrelu4(self.conv4(x))
        x = self.batchnorm3(x)
        x = self.maxpool4(x)
        x = self.dropout4(x)
        
        x = self.leakyrelu5(self.conv5(x))
        x = self.batchnorm4(x)
        x = self.maxpool5(x)
        x = self.dropout5(x)
        
        x = self.flatten(x)
        x = self.leakyrelu5(self.fc1(x))
        
        return x

# Create an instance of the AutismCNN model and move it to the GPU
model = Autism_AdamCNN().to(device)

# %%
import torch.nn as nn

# Define the number of output classes
num_classes = 2

criterion = nn.CrossEntropyLoss()
criterion = criterion.to(device)

# %%
import torch.optim as optim

# Define the hyperparameters
learning_rate = 0.001  # η
beta1 = 0.9  # β1
beta2 = 0.999  # β2
epsilon = 1e-7  # ε

# Create an instance of the Adam optimizer with the specified hyperparameters
optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(beta1, beta2), eps=epsilon)

# %%
from tqdm import tqdm
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import accuracy_score

# Load your pretrained model weights here if needed
#model.load_state_dict(torch.load('Adam_full_weights.pth'))

# Create empty lists to store training and validation losses and accuracies
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Set the current epoch number to continue from where you left off
current_epoch = 0  # Change this to the epoch you want to continue from

num_epochs = 50  # Set the total number of epochs you want to run

# Define early stopping parameters
patience = 5  # Number of epochs with no improvement after which training will stop
min_delta = 0.001  # Minimum change in validation loss to be considered as improvement
best_val_loss = float('inf')
epochs_without_improvement = 0

# Continue training for additional epochs
for epoch in range(current_epoch, num_epochs):
    model.train()
    running_train_loss = 0.0
    train_preds = []
    train_targets = []

    # Training loop with a progress bar
    for images, labels in tqdm(train_loader, desc=f'Epoch {epoch + 1}/{num_epochs} (Training)'):
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_train_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        train_preds.extend(predicted.cpu().numpy())
        train_targets.extend(labels.cpu().numpy())

    # Calculate and print the average training loss for this epoch
    avg_train_loss = running_train_loss / len(train_loader)
    train_losses.append(avg_train_loss)
    
    # Calculate training accuracy for this epoch
    train_accuracy = accuracy_score(train_targets, train_preds)
    train_accuracies.append(train_accuracy)

    model.eval()  # Set the model to evaluation mode
    running_val_loss = 0.0
    val_preds = []
    val_targets = []

    # Validation loop with a progress bar
    for images, labels in tqdm(val_loader, desc=f'Epoch {epoch + 1}/{num_epochs} (Validation)'):
        images, labels = images.to(device), labels.to(device)  # Move data to GPU
        outputs = model(images)
        loss = criterion(outputs, labels)
        running_val_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        val_preds.extend(predicted.cpu().numpy())
        val_targets.extend(labels.cpu().numpy())

    # Calculate and print the average validation loss for this epoch
    avg_val_loss = running_val_loss / len(val_loader)
    val_losses.append(avg_val_loss)
    
    # Calculate validation accuracy for this epoch
    val_accuracy = accuracy_score(val_targets, val_preds)
    val_accuracies.append(val_accuracy)

    # Early stopping
    if avg_val_loss + min_delta < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_without_improvement = 0
        torch.save(model.state_dict(), 'Adam_full_weights.pth')
    else:
        epochs_without_improvement += 1
        if epochs_without_improvement >= patience:
            print(f'Early stopping after {patience} epochs without improvement.')
            break

    # Print loss and accuracy for this epoch
    print(f'Epoch [{epoch + 1}/{num_epochs}], Training Loss: {avg_train_loss:.4f}, Training Accuracy: {train_accuracy:.2f}')
    print(f'Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {val_accuracy:.2f}')

print('Finished Training')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Epoch 1/50 (Training): 100%|██████████| 1131/1131 [06:44<00:00,  2.80it/s]
# Epoch 1/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.40it/s]
# Epoch [1/50], Training Loss: 0.9118, Training Accuracy: 0.51
# Validation Loss: 0.7033, Validation Accuracy: 0.54
# Epoch 2/50 (Training): 100%|██████████| 1131/1131 [06:24<00:00,  2.94it/s]
# Epoch 2/50 (Validation): 100%|██████████| 126/126 [00:39<00:00,  3.15it/s]
# Epoch [2/50], Training Loss: 0.7676, Training Accuracy: 0.52
# Validation Loss: 0.7124, Validation Accuracy: 0.50
# Epoch 3/50 (Training): 100%|██████████| 1131/1131 [06:38<00:00,  2.84it/s]
# Epoch 3/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.29it/s]
# Epoch [3/50], Training Loss: 0.7517, Training Accuracy: 0.54
# Validation Loss: 0.6771, Validation Accuracy: 0.56
# Epoch 4/50 (Training): 100%|██████████| 1131/1131 [06:36<00:00,  2.85it/s]
# Epoch 4/50 (Validation): 100%|██████████| 126/126 [00:39<00:00,  3.22it/s]
# Epoch [4/50], Training Loss: 0.7431, Training Accuracy: 0.56
# Validation Loss: 0.6593, Validation Accuracy: 0.60
# Epoch 5/50 (Training): 100%|██████████| 1131/1131 [06:41<00:00,  2.82it/s]
# Epoch 5/50 (Validation): 100%|██████████| 126/126 [00:39<00:00,  3.20it/s]
# Epoch [5/50], Training Loss: 0.7062, Training Accuracy: 0.58
# Validation Loss: 0.6506, Validation Accuracy: 0.60
# Epoch 6/50 (Training): 100%|██████████| 1131/1131 [06:41<00:00,  2.82it/s]
# Epoch 6/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.37it/s]
# Epoch [6/50], Training Loss: 0.6728, Training Accuracy: 0.60
# Validation Loss: 0.6251, Validation Accuracy: 0.63
# Epoch 7/50 (Training): 100%|██████████| 1131/1131 [06:30<00:00,  2.89it/s]
# Epoch 7/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.39it/s]
# Epoch [7/50], Training Loss: 0.6533, Training Accuracy: 0.62
# Validation Loss: 0.6116, Validation Accuracy: 0.65
# Epoch 8/50 (Training): 100%|██████████| 1131/1131 [06:16<00:00,  3.00it/s]
# Epoch 8/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.37it/s]
# Epoch [8/50], Training Loss: 0.6250, Training Accuracy: 0.64
# Validation Loss: 0.6089, Validation Accuracy: 0.65
# Epoch 9/50 (Training): 100%|██████████| 1131/1131 [06:13<00:00,  3.03it/s]
# Epoch 9/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.31it/s]
# Epoch [9/50], Training Loss: 0.5974, Training Accuracy: 0.67
# Validation Loss: 0.5674, Validation Accuracy: 0.69
# Epoch 10/50 (Training): 100%|██████████| 1131/1131 [06:20<00:00,  2.97it/s]
# Epoch 10/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.39it/s]
# Epoch [10/50], Training Loss: 0.5693, Training Accuracy: 0.69
# Validation Loss: 0.5204, Validation Accuracy: 0.73
# Epoch 11/50 (Training): 100%|██████████| 1131/1131 [06:12<00:00,  3.03it/s]
# Epoch 11/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.27it/s]
# Epoch [11/50], Training Loss: 0.5346, Training Accuracy: 0.72
# Validation Loss: 0.5053, Validation Accuracy: 0.74
# Epoch 12/50 (Training): 100%|██████████| 1131/1131 [06:25<00:00,  2.93it/s]
# Epoch 12/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.27it/s]
# Epoch [12/50], Training Loss: 0.5012, Training Accuracy: 0.74
# Validation Loss: 0.5197, Validation Accuracy: 0.73
# Epoch 13/50 (Training): 100%|██████████| 1131/1131 [06:24<00:00,  2.94it/s]
# Epoch 13/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.26it/s]
# Epoch [13/50], Training Loss: 0.4636, Training Accuracy: 0.77
# Validation Loss: 0.4296, Validation Accuracy: 0.79
# Epoch 14/50 (Training): 100%|██████████| 1131/1131 [06:29<00:00,  2.90it/s]
# Epoch 14/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.29it/s]
# Epoch [14/50], Training Loss: 0.4290, Training Accuracy: 0.79
# Validation Loss: 0.3937, Validation Accuracy: 0.80
# Epoch 15/50 (Training): 100%|██████████| 1131/1131 [06:22<00:00,  2.96it/s]
# Epoch 15/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.36it/s]
# Epoch [15/50], Training Loss: 0.3979, Training Accuracy: 0.80
# Validation Loss: 0.3600, Validation Accuracy: 0.82
# Epoch 16/50 (Training): 100%|██████████| 1131/1131 [06:17<00:00,  2.99it/s]
# Epoch 16/50 (Validation): 100%|██████████| 126/126 [00:36<00:00,  3.43it/s]
# Epoch [16/50], Training Loss: 0.3711, Training Accuracy: 0.82
# Validation Loss: 0.3404, Validation Accuracy: 0.83
# Epoch 17/50 (Training): 100%|██████████| 1131/1131 [06:16<00:00,  3.01it/s]
# Epoch 17/50 (Validation): 100%|██████████| 126/126 [00:37<00:00,  3.39it/s]
# Epoch [17/50], Training Loss: 0.3511, Training Accuracy: 0.83
# Validation Loss: 0.3287, Validation Accuracy: 0.84
# Epoch 18/50 (Training): 100%|██████████| 1131/1131 [06:15<00:00,  3.01it/s]
# Epoch 18/50 (Validation): 100%|██████████| 126/126 [00:35<00:00,  3.52it/s]
# Epoch [18/50], Training Loss: 0.3308, Training Accuracy: 0.84
# Validation Loss: 0.3137, Validation Accuracy: 0.85
# Epoch 19/50 (Training): 100%|██████████| 1131/1131 [06:18<00:00,  2.99it/s]
# Epoch 19/50 (Validation): 100%|██████████| 126/126 [00:40<00:00,  3.11it/s]
# Epoch [19/50], Training Loss: 0.3198, Training Accuracy: 0.85
# Validation Loss: 0.2897, Validation Accuracy: 0.86
# Epoch 20/50 (Training): 100%|██████████| 1131/1131 [06:21<00:00,  2.97it/s]
# Epoch 20/50 (Validation): 100%|██████████| 126/126 [00:31<00:00,  4.00it/s]
# Epoch [20/50], Training Loss: 0.3048, Training Accuracy: 0.85
# Validation Loss: 0.2791, Validation Accuracy: 0.86
# Epoch 21/50 (Training): 100%|██████████| 1131/1131 [06:26<00:00,  2.93it/s]
# Epoch 21/50 (Validation): 100%|██████████| 126/126 [00:41<00:00,  3.05it/s]
# Epoch [21/50], Training Loss: 0.2955, Training Accuracy: 0.86
# Validation Loss: 0.2773, Validation Accuracy: 0.86
# Epoch 22/50 (Training): 100%|██████████| 1131/1131 [06:27<00:00,  2.92it/s]
# Epoch 22/50 (Validation): 100%|██████████| 126/126 [00:32<00:00,  3.82it/s]
# Epoch [22/50], Training Loss: 0.2796, Training Accuracy: 0.87
# Validation Loss: 0.2721, Validation Accuracy: 0.87
# Epoch 23/50 (Training): 100%|██████████| 1131/1131 [06:16<00:00,  3.01it/s]
# Epoch 23/50 (Validation): 100%|██████████| 126/126 [00:36<00:00,  3.41it/s]
# Epoch [23/50], Training Loss: 0.2680, Training Accuracy: 0.87
# Validation Loss: 0.2776, Validation Accuracy: 0.87
# Epoch 24/50 (Training): 100%|██████████| 1131/1131 [06:29<00:00,  2.90it/s]
# Epoch 24/50 (Validation): 100%|██████████| 126/126 [00:38<00:00,  3.30it/s]
# Epoch [24/50], Training Loss: 0.2633, Training Accuracy: 0.87
# Validation Loss: 0.2531, Validation Accuracy: 0.88
# Epoch 25/50 (Training): 100%|██████████| 1131/1131 [06:06<00:00,  3.09it/s]
# Epoch 25/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.17it/s]
# Epoch [25/50], Training Loss: 0.2529, Training Accuracy: 0.88
# Validation Loss: 0.2854, Validation Accuracy: 0.86
# Epoch 26/50 (Training): 100%|██████████| 1131/1131 [05:48<00:00,  3.25it/s]
# Epoch 26/50 (Validation): 100%|██████████| 126/126 [00:31<00:00,  4.01it/s]
# Epoch [26/50], Training Loss: 0.2513, Training Accuracy: 0.88
# Validation Loss: 0.2525, Validation Accuracy: 0.88
# Epoch 27/50 (Training): 100%|██████████| 1131/1131 [05:52<00:00,  3.21it/s]
# Epoch 27/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.10it/s]
# Epoch [27/50], Training Loss: 0.2388, Training Accuracy: 0.89
# Validation Loss: 0.2509, Validation Accuracy: 0.88
# Epoch 28/50 (Training): 100%|██████████| 1131/1131 [05:44<00:00,  3.29it/s]
# Epoch 28/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.07it/s]
# Epoch [28/50], Training Loss: 0.2345, Training Accuracy: 0.89
# Validation Loss: 0.2417, Validation Accuracy: 0.88
# Epoch 29/50 (Training): 100%|██████████| 1131/1131 [05:48<00:00,  3.25it/s]
# Epoch 29/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.15it/s]
# Epoch [29/50], Training Loss: 0.2312, Training Accuracy: 0.89
# Validation Loss: 0.2327, Validation Accuracy: 0.88
# Epoch 30/50 (Training): 100%|██████████| 1131/1131 [05:40<00:00,  3.32it/s]
# Epoch 30/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.12it/s]
# Epoch [30/50], Training Loss: 0.2254, Training Accuracy: 0.89
# Validation Loss: 0.2331, Validation Accuracy: 0.89
# Epoch 31/50 (Training): 100%|██████████| 1131/1131 [05:41<00:00,  3.31it/s]
# Epoch 31/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.18it/s]
# Epoch [31/50], Training Loss: 0.2248, Training Accuracy: 0.90
# Validation Loss: 0.2285, Validation Accuracy: 0.89
# Epoch 32/50 (Training): 100%|██████████| 1131/1131 [05:36<00:00,  3.37it/s]
# Epoch 32/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.16it/s]
# Epoch [32/50], Training Loss: 0.2177, Training Accuracy: 0.90
# Validation Loss: 0.2286, Validation Accuracy: 0.89
# Epoch 33/50 (Training): 100%|██████████| 1131/1131 [05:39<00:00,  3.34it/s]
# Epoch 33/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.12it/s]
# Epoch [33/50], Training Loss: 0.2083, Training Accuracy: 0.90
# Validation Loss: 0.2192, Validation Accuracy: 0.89
# Epoch 34/50 (Training): 100%|██████████| 1131/1131 [05:44<00:00,  3.29it/s]
# Epoch 34/50 (Validation): 100%|██████████| 126/126 [00:33<00:00,  3.81it/s]
# Epoch [34/50], Training Loss: 0.2075, Training Accuracy: 0.90
# Validation Loss: 0.2486, Validation Accuracy: 0.88
# Epoch 35/50 (Training): 100%|██████████| 1131/1131 [05:39<00:00,  3.33it/s]
# Epoch 35/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.10it/s]
# Epoch [35/50], Training Loss: 0.2077, Training Accuracy: 0.90
# Validation Loss: 0.2126, Validation Accuracy: 0.89
# Epoch 36/50 (Training): 100%|██████████| 1131/1131 [05:44<00:00,  3.28it/s]
# Epoch 36/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.07it/s]
# Epoch [36/50], Training Loss: 0.2000, Training Accuracy: 0.91
# Validation Loss: 0.2132, Validation Accuracy: 0.90
# Epoch 37/50 (Training): 100%|██████████| 1131/1131 [05:38<00:00,  3.34it/s]
# Epoch 37/50 (Validation): 100%|██████████| 126/126 [00:29<00:00,  4.21it/s]
# Epoch [37/50], Training Loss: 0.1989, Training Accuracy: 0.91
# Validation Loss: 0.2108, Validation Accuracy: 0.90
# Epoch 38/50 (Training): 100%|██████████| 1131/1131 [05:38<00:00,  3.34it/s]
# Epoch 38/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.07it/s]
# Epoch [38/50], Training Loss: 0.1913, Training Accuracy: 0.91
# Validation Loss: 0.2130, Validation Accuracy: 0.90
# Epoch 39/50 (Training): 100%|██████████| 1131/1131 [05:47<00:00,  3.25it/s]
# Epoch 39/50 (Validation): 100%|██████████| 126/126 [00:33<00:00,  3.75it/s]
# Epoch [39/50], Training Loss: 0.1904, Training Accuracy: 0.91
# Validation Loss: 0.2068, Validation Accuracy: 0.90
# Epoch 40/50 (Training): 100%|██████████| 1131/1131 [05:54<00:00,  3.19it/s]
# Epoch 40/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.09it/s]
# Epoch [40/50], Training Loss: 0.1866, Training Accuracy: 0.91
# Validation Loss: 0.2042, Validation Accuracy: 0.90
# Epoch 41/50 (Training): 100%|██████████| 1131/1131 [05:40<00:00,  3.32it/s]
# Epoch 41/50 (Validation): 100%|██████████| 126/126 [00:31<00:00,  4.00it/s]
# Epoch [41/50], Training Loss: 0.1852, Training Accuracy: 0.91
# Validation Loss: 0.2015, Validation Accuracy: 0.90
# Epoch 42/50 (Training): 100%|██████████| 1131/1131 [05:37<00:00,  3.35it/s]
# Epoch 42/50 (Validation): 100%|██████████| 126/126 [00:31<00:00,  4.06it/s]
# Epoch [42/50], Training Loss: 0.1805, Training Accuracy: 0.92
# Validation Loss: 0.2067, Validation Accuracy: 0.91
# Epoch 43/50 (Training): 100%|██████████| 1131/1131 [05:32<00:00,  3.40it/s]
# Epoch 43/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.16it/s]
# Epoch [43/50], Training Loss: 0.1796, Training Accuracy: 0.92
# Validation Loss: 0.2094, Validation Accuracy: 0.90
# Epoch 44/50 (Training): 100%|██████████| 1131/1131 [05:29<00:00,  3.44it/s]
# Epoch 44/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.17it/s]
# Epoch [44/50], Training Loss: 0.1731, Training Accuracy: 0.92
# Validation Loss: 0.2039, Validation Accuracy: 0.91
# Epoch 45/50 (Training): 100%|██████████| 1131/1131 [05:31<00:00,  3.41it/s]
# Epoch 45/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.09it/s]
# Epoch [45/50], Training Loss: 0.1742, Training Accuracy: 0.92
# Validation Loss: 0.2064, Validation Accuracy: 0.90
# Epoch 46/50 (Training): 100%|██████████| 1131/1131 [05:27<00:00,  3.46it/s]
# Epoch 46/50 (Validation): 100%|██████████| 126/126 [00:30<00:00,  4.17it/s]
# Early stopping after 5 epochs without improvement.
# Finished Training

# %%
#Training vs Validation accuracies
import matplotlib.pyplot as plt

# Find the minimum number of epochs (between num_epochs and the number of epochs actually completed)
min_epochs = min(num_epochs, len(train_accuracies))

plt.figure(figsize=(6, 4))
plt.plot(range(1, min_epochs + 1), train_accuracies[:min_epochs], label='Train_Accuracy', marker='o')
plt.plot(range(1, min_epochs + 1), val_accuracies[:min_epochs], label='Val_Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training vs. Validation Accuracies')
plt.legend()
plt.grid(True)
plt.show()

# %%
#Training vs Validation loss
import matplotlib.pyplot as plt

# Find the minimum number of epochs (between num_epochs and the number of epochs actually completed)
min_epochs = min(num_epochs, len(train_losses))

plt.figure(figsize=(6, 4))
plt.plot(range(1, min_epochs + 1), train_losses[:min_epochs], label='Train_Loss', marker='o')
plt.plot(range(1, min_epochs + 1), val_losses[:min_epochs], label='Val_Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Validation Loss')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, roc_auc_score, roc_curve, confusion_matrix, classification_report, f1_score, recall_score
import torch

# Initialize empty lists to store true labels and predicted class probabilities
true_labels = []
predicted_probs = []

# Set the model to evaluation mode
model.eval()

# Move the model to the GPU
model = model.to(device)

with torch.no_grad():
    for images, labels in test_loader:
        # Move the data to the GPU
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)

        # Get the predicted class probabilities using softmax
        predicted_probs.extend(torch.softmax(outputs, dim=1)[:, 1].cpu().numpy())  # Probability of class 1

        # Store true labels
        true_labels.extend(labels.cpu().numpy())

# Calculate the accuracy
predicted_labels = [1 if prob >= 0.5 else 0 for prob in predicted_probs]
accuracy = accuracy_score(true_labels, predicted_labels)

# Calculate the AUC
roc_auc = roc_auc_score(true_labels, predicted_probs)

# Calculate precision, recall, and F1 score
precision = precision_score(true_labels, predicted_labels)
recall = recall_score(true_labels, predicted_labels)
f1 = f1_score(true_labels, predicted_labels)

# Calculate sensitivity (True Positive Rate)
conf_matrix = confusion_matrix(true_labels, predicted_labels)
sensitivity = conf_matrix[1, 1] / (conf_matrix[1, 1] + conf_matrix[1, 0])

# Calculate specificity (True Negative Rate)
specificity = conf_matrix[0, 0] / (conf_matrix[0, 0] + conf_matrix[0, 1])

# Print the results
print(f'AUC: {roc_auc:.2f}')
print(f'Accuracy: {accuracy:.2f}')
print(f'Precision: {precision:.2f}')
print(f'Recall (Sensitivity): {recall:.2f}')
print(f'Specificity: {specificity:.2f}')
print(f'F1 Score: {f1:.2f}')
# Out:
# AUC: 0.97
# Accuracy: 0.90
# Precision: 0.87
# Recall (Sensitivity): 0.93
# Specificity: 0.87
# F1 Score: 0.90

# %%
import matplotlib.pyplot as plt

# ROC Curve
fpr, tpr, thresholds = roc_curve(true_labels, predicted_probs)
plt.figure(figsize=(6, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc='lower right')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Access values from the confusion matrix
TN = conf_matrix[0, 0]
FP = conf_matrix[0, 1]
FN = conf_matrix[1, 0]
TP = conf_matrix[1, 1]

# Now you can use these values as needed

# Define the confusion matrix
conf_matrix = np.array([[TN, FP], [FN, TP]])  

# Confusion Matrix
plt.figure(figsize=(6, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)

# Annotate cells with their values
thresh = conf_matrix.max() / 2.0  # Set a threshold for text coloring
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        plt.text(j, i, str(conf_matrix[i, j]), horizontalalignment="center",
                 color="white" if conf_matrix[i, j] > thresh else "black")

plt.title('Confusion Matrix')
plt.colorbar()
plt.xticks([0, 1], ['Predicted 0', 'Predicted 1'])
plt.yticks([0, 1], ['Actual 0', 'Actual 1'])
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
